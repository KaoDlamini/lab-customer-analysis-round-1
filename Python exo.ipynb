# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Read the three files into python as dataframes

# %%
df1= pd.read_csv(r'C:\Users\kaohs\Desktop\Ironhack 2024\Labs\lab-customer-analysis-round-1\files_for_lab\csv_files\file1.csv',sep =',')
df1.head(10)
# Out:
#   Customer          ST GENDER             Education Customer Lifetime Value  \
# 0  RB50392  Washington    NaN                Master                     NaN
# 1  QZ44356     Arizona      F              Bachelor              697953.59%
# 2  AI49188      Nevada      F              Bachelor             1288743.17%
# 3  WW63253  California      M              Bachelor              764586.18%
# 4  GA49547  Washington      M  High School or Below              536307.65%
# 5  OC83172      Oregon      F              Bachelor              825629.78%
# 6  XZ87318      Oregon      F               College              538089.86%
# 7  CF85061     Arizona      M                Master              721610.03%
# 8  DY87989      Oregon      M              Bachelor             2412750.40%
# 9  BQ94931      Oregon      F               College              738817.81%
#
#     Income  Monthly Premium Auto Number of Open Complaints     Policy Type  \
# ...

# %%
df2= pd.read_csv(r'C:\Users\kaohs\Desktop\Ironhack 2024\Labs\lab-customer-analysis-round-1\files_for_lab\csv_files\file2.csv',sep =',')
df2.head(10)
# Out:
#   Customer          ST GENDER Education Customer Lifetime Value  Income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    Monthly Premium Auto Number of Open Complaints  Total Claim Amount  \
# 0                    88                    1/0/00          633.600000
# ...

# %%
df3= pd.read_csv(r'C:\Users\kaohs\Desktop\Ironhack 2024\Labs\lab-customer-analysis-round-1\files_for_lab\csv_files\file3.csv',sep =','
        )
df3.head(10)
# Out:
#   Customer       State  Customer Lifetime Value             Education Gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    Income  Monthly Premium Auto  Number of Open Complaints     Policy Type  \
# ...

# %% [markdown]
# Show the DataFrame's shape.

# %%
df1.shape
# Out:
# (4008, 11)

# %%
df2.shape
# Out:
# (996, 11)

# %%
df3.shape
# Out:
# (7070, 11)

# %% [markdown]
# Standardize header names.

# %%
df1.columns = df1.columns.str.lower().str.replace(" ", "_")
df1
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 4003      NaN         NaN    NaN                   NaN
# 4004      NaN         NaN    NaN                   NaN
# 4005      NaN         NaN    NaN                   NaN
# 4006      NaN         NaN    NaN                   NaN
# 4007      NaN         NaN    NaN                   NaN
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
df2.columns = df2.columns.str.lower().str.replace(" ", "_")
df2
# Out:
#     customer          st gender education customer_lifetime_value  income  \
# 0    GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1    CW49887  California      F    Master              462680.11%   79487
# 2    MY31220  California      F   College              899704.02%   54230
# 3    UH35128      Oregon      F   College             2580706.30%   71210
# 4    WH52799     Arizona      F   College              380812.21%   94903
# ..       ...         ...    ...       ...                     ...     ...
# 991  HV85198     Arizona      M    Master              847141.75%   63513
# 992  BS91566     Arizona      F   College              543121.91%   58161
# 993  IL40123      Nevada      F   College              568964.41%   83640
# 994  MY32149  California      F    Master              368672.38%       0
# 995  SA91515  California      M  Bachelor              399258.39%       0
#
#      monthly_premium_auto number_of_open_complaints  total_claim_amount  \
# ...

# %%
df3.columns = df3.columns.str.lower().str.replace(" ", "_")
df3
# Out:
#      customer       state  customer_lifetime_value             education  \
# 0     SA25987  Washington              3479.137523  High School or Below
# 1     TB86706     Arizona              2502.637401                Master
# 2     ZL73902      Nevada              3265.156348              Bachelor
# 3     KX23516  California              4455.843406  High School or Below
# 4     FN77294  California              7704.958480  High School or Below
# ...       ...         ...                      ...                   ...
# 7065  LA72316  California             23405.987980              Bachelor
# 7066  PK87824  California              3096.511217               College
# 7067  TD14365  California              8163.890428              Bachelor
# 7068  UP19263  California              7524.442436               College
# 7069  Y167826  California              2611.836866               College
#
#      gender  income  monthly_premium_auto  number_of_open_complaints  \
# ...

# %% [markdown]
# Rearrange the columns in the dataframe as needed

# %%
df1.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'vehicle_class', 'total_claim_amount'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'total_claim_amount', 'policy_type', 'vehicle_class'],
#       dtype='object')

# %%
df3.columns
# Out:
# Index(['customer', 'state', 'customer_lifetime_value', 'education', 'gender',
#        'income', 'monthly_premium_auto', 'number_of_open_complaints',
#        'policy_type', 'total_claim_amount', 'vehicle_class'],
#       dtype='object')

# %%
rearranged= ['customer', 'st', 'gender', 'education', 'customer_lifetime_value',
       'income', 'monthly_premium_auto', 'number_of_open_complaints',
       'policy_type', 'vehicle_class', 'total_claim_amount']

# %%
df2= df2[rearranged]
df2.head(10)
# Out:
#   customer          st gender education customer_lifetime_value  income  \
# 0  GS98873     Arizona      F  Bachelor              323912.47%   16061
# 1  CW49887  California      F    Master              462680.11%   79487
# 2  MY31220  California      F   College              899704.02%   54230
# 3  UH35128      Oregon      F   College             2580706.30%   71210
# 4  WH52799     Arizona      F   College              380812.21%   94903
# 5  WL99637     Arizona      M  Bachelor              761413.80%   27293
# 6  UC84059  California      F    Master              689845.53%   70950
# 7  HW62747      Oregon      M   College              229837.92%       0
# 8  BH11344      Oregon      F    Doctor              280669.61%   37009
# 9  TX28465      Nevada      M   College              520611.82%   52629
#
#    monthly_premium_auto number_of_open_complaints     policy_type  \
# 0                    88                    1/0/00   Personal Auto
# ...

# %%
df3.rename(columns={'state': 'st'}, inplace=True)
df3.head(10)
# Out:
#   customer          st  customer_lifetime_value             education gender  \
# 0  SA25987  Washington              3479.137523  High School or Below      M
# 1  TB86706     Arizona              2502.637401                Master      M
# 2  ZL73902      Nevada              3265.156348              Bachelor      F
# 3  KX23516  California              4455.843406  High School or Below      F
# 4  FN77294  California              7704.958480  High School or Below      M
# 5  VI78454     Arizona              2750.705045               College      M
# 6  FP59138      Oregon             13024.130120                Master      M
# 7  XN62489      Oregon              2538.626320              Bachelor      M
# 8  GP66031  California              2585.955652               College      F
# 9  IX68587      Nevada              5096.673223                Master      F
#
#    income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %%
df3= df3[rearranged]
df3.head(10)
# Out:
#   customer          st gender             education  customer_lifetime_value  \
# 0  SA25987  Washington      M  High School or Below              3479.137523
# 1  TB86706     Arizona      M                Master              2502.637401
# 2  ZL73902      Nevada      F              Bachelor              3265.156348
# 3  KX23516  California      F  High School or Below              4455.843406
# 4  FN77294  California      M  High School or Below              7704.958480
# 5  VI78454     Arizona      M               College              2750.705045
# 6  FP59138      Oregon      M                Master             13024.130120
# 7  XN62489      Oregon      M              Bachelor              2538.626320
# 8  GP66031  California      F               College              2585.955652
# 9  IX68587      Nevada      F                Master              5096.673223
#
#    income  monthly_premium_auto  number_of_open_complaints     policy_type  \
# ...

# %% [markdown]
# Concatenate the three dataframes

# %%
combin_dfs = pd.concat([df1, df2, df3], axis=0)
combin_dfs
# Out:
#      customer          st gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer_lifetime_value   income  monthly_premium_auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %% [markdown]
# Which columns are numerical?

# %%
combin_dfs.dtypes
# Out:
# customer                      object
# st                            object
# gender                        object
# education                     object
# customer_lifetime_value       object
# income                       float64
# monthly_premium_auto         float64
# number_of_open_complaints     object
# policy_type                   object
# vehicle_class                 object
# total_claim_amount           float64
# dtype: object

# %% [markdown]
# ### All of the floats are numerical values and so is customer life value , it is giving object because it sometimes has the '%' and so is the number of complaints

# %% [markdown]
# Which columns are categorical?

# %% [markdown]
# ### The remaining columns that are an object are categorical.

# %% [markdown]
# Understand the meaning of all columns

# %% [markdown]
# Perform the data cleaning operations mentioned so far in class
#
#     Delete the column education and the number of open complaints from the dataframe.

# %%
combin_dfs = combin_dfs.drop(columns=["education","number_of_open_complaints"])

# %%
combin_dfs
# Out:
#      customer          st gender customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                     NaN      0.0
# 1     QZ44356     Arizona      F              697953.59%      0.0
# 2     AI49188      Nevada      F             1288743.17%  48767.0
# 3     WW63253  California      M              764586.18%      0.0
# 4     GA49547  Washington      M              536307.65%  36357.0
# ...       ...         ...    ...                     ...      ...
# 7065  LA72316  California      M             23405.98798  71941.0
# 7066  PK87824  California      F             3096.511217  21604.0
# 7067  TD14365  California      M             8163.890428      0.0
# 7068  UP19263  California      M             7524.442436  21941.0
# 7069  Y167826  California      M             2611.836866      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
# Correct the values in the column customer lifetime value. They are given as a percent, so multiply them by 100 and change dtype to numerical type.

# %%
combin_dfs['customer_lifetime_value'] = combin_dfs['customer_lifetime_value'].str.replace('%', '')
combin_dfs['customer_lifetime_value']
# Out:
# 0              NaN
# 1        697953.59
# 2       1288743.17
# 3        764586.18
# 4        536307.65
#            ...
# 7065           NaN
# 7066           NaN
# 7067           NaN
# 7068           NaN
# 7069           NaN
# Name: customer_lifetime_value, Length: 12074, dtype: object

# %%
combin_dfs['customer_lifetime_value'] = combin_dfs['customer_lifetime_value'].astype(float)*100
combin_dfs['customer_lifetime_value']
# Out:
# 0               NaN
# 1        69795359.0
# 2       128874317.0
# 3        76458618.0
# 4        53630765.0
#            ...
# 7065            NaN
# 7066            NaN
# 7067            NaN
# 7068            NaN
# 7069            NaN
# Name: customer_lifetime_value, Length: 12074, dtype: float64

# %% [markdown]
#     Check for duplicate rows in the data and remove if any.

# %%
combin_dfs.drop_duplicates()
combin_dfs
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 0     RB50392  Washington    NaN                      NaN      0.0
# 1     QZ44356     Arizona      F               69795359.0      0.0
# 2     AI49188      Nevada      F              128874317.0  48767.0
# 3     WW63253  California      M               76458618.0      0.0
# 4     GA49547  Washington      M               53630765.0  36357.0
# ...       ...         ...    ...                      ...      ...
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7067  TD14365  California      M                      NaN      0.0
# 7068  UP19263  California      M                      NaN  21941.0
# 7069  Y167826  California      M                      NaN      0.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 0                   1000.0   Personal Auto  Four-Door Car            2.704934
# ...

# %% [markdown]
#     Filter out the data for customers who have an income of 0 or less.

# %%
filtered_combin_dfs = combin_dfs[combin_dfs['income'] > 0]
filtered_combin_dfs
# Out:
#      customer          st gender  customer_lifetime_value   income  \
# 2     AI49188      Nevada      F              128874317.0  48767.0
# 4     GA49547  Washington      M               53630765.0  36357.0
# 5     OC83172      Oregon      F               82562978.0  62902.0
# 6     XZ87318      Oregon      F               53808986.0  55350.0
# 8     DY87989      Oregon      M              241275040.0  14072.0
# ...       ...         ...    ...                      ...      ...
# 7063  TF56202  California      M                      NaN  66367.0
# 7064  YM19146  California      F                      NaN  47761.0
# 7065  LA72316  California      M                      NaN  71941.0
# 7066  PK87824  California      F                      NaN  21604.0
# 7068  UP19263  California      M                      NaN  21941.0
#
#       monthly_premium_auto     policy_type  vehicle_class  total_claim_amount
# 2                    108.0   Personal Auto   Two-Door Car          566.472247
# ...
